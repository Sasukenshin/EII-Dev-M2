# %%
df <- iris

# %%
df
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...

# %% [markdown]
# Q. Add new column total length = sepal length + petal length

# %%
df["Total.Length"] = df["Sepal.Length"] + df["Petal.Length"]

# %% [markdown]
# Q. Make a new column "length_categorical": if total length < 6: "short", > 6.5: "long", between 6 and 6.5: "medium"

# %%
df$length_categorical <- "medium"
df$length_categorical[df$Total.Length<6] <- "short"
df$length_categorical[df$Total.Length>6.5] <- "long"
# df$length_categorical[df$Total.Length %between% c(6,6.5)] <- "medium"
df
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species   Total.Length
# 1   5.1          3.5         1.4          0.2         setosa    6.5
# 2   4.9          3.0         1.4          0.2         setosa    6.3
# 3   4.7          3.2         1.3          0.2         setosa    6.0
# 4   4.6          3.1         1.5          0.2         setosa    6.1
# 5   5.0          3.6         1.4          0.2         setosa    6.4
# 6   5.4          3.9         1.7          0.4         setosa    7.1
# 7   4.6          3.4         1.4          0.3         setosa    6.0
# 8   5.0          3.4         1.5          0.2         setosa    6.5
# 9   4.4          2.9         1.4          0.2         setosa    5.8
# 10  4.9          3.1         1.5          0.1         setosa    6.4
# 11  5.4          3.7         1.5          0.2         setosa    6.9
# 12  4.8          3.4         1.6          0.2         setosa    6.4
# 13  4.8          3.0         1.4          0.1         setosa    6.2
# ...

# %% [markdown]
# Q. Install and load package HSAUR3, then print the Forbes2000 dataset

# %%
install.packages("HSAUR3")
library(HSAUR3)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Loading required package: tools

# %%
Forbes2000
# Out:
#      rank name                      country
# 1     1   Citigroup                 United States
# 2     2   General Electric          United States
# 3     3   American Intl Group       United States
# 4     4   ExxonMobil                United States
# 5     5   BP                        United Kingdom
# 6     6   Bank of America           United States
# 7     7   HSBC Group                United Kingdom
# 8     8   Toyota Motor              Japan
# 9     9   Fannie Mae                United States
# 10   10   Wal-Mart Stores           United States
# 11   11   UBS                       Switzerland
# 12   12   ING Group                 Netherlands
# 13   13   Royal Dutch/Shell Group   Netherlands/ United Kingdom
# 14   14   Berkshire Hathaway        United States
# 15   15   JP Morgan Chase           United States
# 16   16   IBM                       United States
# 17   17   Total                     France
# 18   18   BNP Paribas               France
# ...

# %% [markdown]
# Q. Sort by Market values

# %%
attach(Forbes2000)

# %%
newdata <- Forbes2000[order(marketvalue),]
newdata
# Out:
#      rank name                     country
# 1450 1450 Federal-Mogul            United States
# 1504 1504 Owens Corning            United States
# 1952 1952 Finova Group             United States
# 1600 1600 Hyundai South            Korea
# 1783 1783 Hanshin Construction     South Korea
# 1409 1409 Kumho Industrial         South Korea
# 1867 1867 Aplus                    Japan
# 1875 1875 MyTravel Group           United Kingdom
# 1586 1586 Air Canada               Canada
# 1322 1322 KKPC-Korea Kumho         South Korea
# 1807 1807 Rashid Hussain           Malaysia
# 1962 1962 Iwataya Department Store Japan
# 1039 1039 UAL                      United States
# 1749 1749 Kumagai Gumi             Japan
# 1906 1906 Nippon Steel Trading     Japan
# 1268 1268 Mirant                   United States
# 1629 1629 Doosan                   South Korea
# 876   876 LG Card                  South Korea
# 1847 1847 Sumikin Bussan           Japan
# 1425 1425 US Airways Group         United States
# ...

# %% [markdown]
# Q. Sort by profits

# %%
newdata <- Forbes2000[order(profits),]
newdata
# Out:
#      rank name                      country
# 364   364 Deutsche Telekom          Germany
# 374   374 France Telecom            France
# 403   403 Mizuho Financial          Japan
# 687   687 mmO2                      United Kingdom
# 354   354 Vodafone                  United Kingdom
# 895   895 Cable & Wireless          United Kingdom
# 577   577 Royal KPN                 Netherlands
# 563   563 Resona Holdings           Japan
# 409   409 Telefsnica                Spain
# 444   444 UFJ Holdings              Japan
# 435   435 Vivendi Universal         France
# 561   561 Alcatel                   France
# 1268 1268 Mirant                    United States
# 552   552 Fiat Group                Italy
# 683   683 TXU                       United States
# 405   405 Zurich Financial Services Switzerland
# 396   396 Sumitomo Mitsui Financial Japan
# 1039 1039 UAL                       United States
# 1994 1994 Mobilcom                  Germany
# ...

# %% [markdown]
# Q. Print out companies with negative Profits

# %%
newdata <- subset(Forbes2000, profits <0, select=c(name)) 
newdata
# Out:
#      name
# 350  Allianz Worldwide
# 354  Vodafone
# 364  Deutsche Telekom
# 372  Credit Suisse Group
# 374  France Telecom
# 382  Generali Group
# 396  Sumitomo Mitsui Financial
# 397  E.ON
# 398  Mitsubishi Tokyo Finl
# 402  Aviva
# 403  Mizuho Financial
# 405  Zurich Financial Services
# 409  Telefsnica
# 412  Telecom Italia
# 415  Matsushita Electric Indl
# 427  Suez Group
# 431  HVB-HypoVereinsbank
# 435  Vivendi Universal
# 438  Swiss Re Group
# 444  UFJ Holdings
# 460  Philips Group
# 466  Hartford Finl Service
# 470  Legal & General Group
# 482  EADS
# 488  Duke Energy
# 494  Abbey National
# 500  Commerzbank
# 524  Fujitsu
# 529  Ahold
# 535  Loews
# ...  ...
# 1863 International Steel Group
# 1865 Siam Commercial Bank
# 1868 Woodside Petroleum
# 1875 MyTravel Group
# 1880 Nisshin Steel
# 1885 Vishay Intertech
# 1887 SPAR Handels
# 1890 Sierra Pacific Res
# 1891 Advantest
# 1892 Farmers Bank of China
# 1897 Towa Bank
# 1905 Research In Motion
# 1906 Nippon Steel Trading
# ...

# %% [markdown]
# Q. Find and print all rows containing NA values, then drop them from the dataset

# %%
# x <- Forbes2000[complete.cases(Forbes2000), ]
df <- na.omit(Forbes2000)
df
# new_Forbes2000 <- Forbes2000[rowSums(is.na(Forbes2000)) > 0,]
# new_Forbes2000
# Out:
#      rank name                      country
# 1     1   Citigroup                 United States
# 2     2   General Electric          United States
# 3     3   American Intl Group       United States
# 4     4   ExxonMobil                United States
# 5     5   BP                        United Kingdom
# 6     6   Bank of America           United States
# 7     7   HSBC Group                United Kingdom
# 8     8   Toyota Motor              Japan
# 9     9   Fannie Mae                United States
# 10   10   Wal-Mart Stores           United States
# 11   11   UBS                       Switzerland
# 12   12   ING Group                 Netherlands
# 13   13   Royal Dutch/Shell Group   Netherlands/ United Kingdom
# 14   14   Berkshire Hathaway        United States
# 15   15   JP Morgan Chase           United States
# 16   16   IBM                       United States
# 17   17   Total                     France
# 18   18   BNP Paribas               France
# ...

# %% [markdown]
# Q. Print all companies in UK

# %%
newdata <- subset(df, country == "United Kingdom", select=c(name))
newdata
# Out:
#      name
# 5    BP
# 7    HSBC Group
# 19   Royal Bank of Scotland
# 27   Barclays
# 36   HBOS
# 47   Lloyds TSB Group
# 80   GlaxoSmithKline
# 93   BT Group
# 105  Prudential
# 119  AstraZeneca
# 120  Tesco
# 137  Anglo American
# 155  British Amer Tobacco
# 182  National Grid Transco
# 200  Standard Chartered Group
# 245  Centrica
# 249  J Sainsbury
# 308  Scottish Power
# 331  Cadbury Schweppes
# 341  Compass Group
# 344  Marks & Spencer
# 348  Old Mutual
# 352  Kingfisher
# 354  Vodafone
# 367  GUS
# 401  Alliance & Leicester
# 402  Aviva
# 406  Diageo
# 411  Imperial Tobacco Group
# 446  Northern Rock
# ...  ...
# 1472 Hammerson
# 1505 Inchcape
# 1513 William Hill Org
# 1526 Sage Group
# 1535 Pilkington
# 1574 Hays
# 1628 Canary Wharf Group
# 1652 FirstGroup
# 1665 Provident Financial Plc
# 1673 Schroders
# 1704 EMAP
# 1738 Shire Pharmaceuticals
# 1750 Travis Perkins
# 1774 AWG
# 1781 Britannic Group
# 1782 Marconi
# 1795 BPB
# 1812 Big Food Group
# 1840 LogicaCMG
# ...

# %% [markdown]
# Q. Compute avearage profit by industry category

# %%
# Out:
#              Aerospace & defense                          Banking
#                        0.2884211                        0.4220767
#     Business services & supplies                    Capital goods
#                        0.1707143                        0.0954717
#                        Chemicals                    Conglomerates
#                        0.2606000                        1.0145161
#                     Construction                Consumer durables
#                        0.1981013                        0.5663514
#           Diversified financials            Drugs & biotechnology
#                        0.4995570                        1.4477778
#             Food drink & tobacco                     Food markets
#                        0.5938554                        0.2490909
# Health care equipment & services     Hotels restaurants & leisure
#                        0.3609231                        0.2586486
# ...

# %%
ind <- tapply(df$profits, df$category, mean)
ind

# %% [markdown]
# Q. Print top 3 most profit industries

# %%
sort(ind, decreasing = TRUE)[1:3]
# Out:
# Drugs & biotechnology  Oil & gas operations         Conglomerates
#              1.447778              1.305556              1.014516

# %% [markdown]
# Q. Make the following scatter plot

# %%
plot(log(df$sale), log(df$marketvalue), cex=0.3)
# Out:
# plot without title
