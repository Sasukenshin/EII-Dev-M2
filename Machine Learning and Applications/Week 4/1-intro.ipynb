# %%
age <- c(1,3,5,2,11,9,3,9,12,3)
weight <- c(4.4,5.3,7.2,5.2,8.5,7.3,6.0,10.4,10.2,6.1)

# %%
age
# Out:
#  [1]  1  3  5  2 11  9  3  9 12  3

# %% [markdown]
# Q: Print out mean and standard deviation of weight

# %%
mean(weight)
sd(weight)
# Out:
# [1] 7.06
# [1] 2.077498

# %% [markdown]
# Q: Print correlation between age and weight

# %%
cor(age,weight, method="pearson")
# Out:
# [1] 0.9075655

# %% [markdown]
# Q. Make a scatter plot between age and weight

# %%
plot(age, weight, main="Scatterplot", xlab="Age ", ylab="Weight ",)
# Out:
# Plot with title “Scatterplot”

# %% [markdown]
# Q. Generate a vector x of 20 random numbers between 0 and 1 (uniform distribution)

# %%
x <- runif(n = 20, min = 0, max = 1)
x
# Out:
#  [1] 0,76530727 0,73116568 0,29967088 0,77309345 0,09641934 0,78947105
#  [7] 0,58895093 0,20946831 0,21501852 0,31492622 0,44289860 0,18954672
# [13] 0,36788849 0,84576553 0,51426827 0,08962651 0,11627426 0,28506278
# [19] 0,97713729 0,02228006

# %%
# Out:
#  [1] 0,61535244 0,61308053 0,40916478 0,55766430 0,21489258 0,75778619
#  [7] 0,63061140 0,55179364 0,19484674 0,16298595 0,46260078 0,22593529
# [13] 0,22263476 0,05729418 0,49285361 0,07757983 0,24974720 0,48796151
# [19] 0,87969351 0,29495434

# %% [markdown]
# Q. Print summary min, max, median , 1st-quartile, 3rd-quartile of x

# %%
summary(x)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0,02228 0,20449 0,34141 0,43171 0,73970 0,97714

# %%
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0,05729 0,22070 0,43588 0,40797 0,57152 0,87969

# %% [markdown]
# Q. Make histogram of x

# %%
hist(x)
# Out:
# Plot with title “Histogram of x”

# %%
# Out:
# Plot with title “Histogram of x”

# %% [markdown]
# Q. Make a horizontal bar plot of x

# %%
# Out:
# Plot with title “Horizontal Bar Plot”

# %%
barplot(x, horiz=TRUE)
# Out:
# plot without title

# %% [markdown]
# ### Packages

# %% [markdown]
# Here is how we install a new package, read its documentation, and load the package

# %%
install.packages("vcd")
# Out:
# also installing the dependency ‘lmtest’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
help(package="vcd")

# %%
library(vcd) # Load the package
# Out:
# Loading required package: grid

# %%
Arthritis # Arthritis is part of the package
# Out:
#     ID  Treatment Sex    Age Improved
# 1   57  Treated   Male   27  Some
# 2   46  Treated   Male   29  None
# 3   77  Treated   Male   30  None
# 4   17  Treated   Male   32  Marked
# 5   36  Treated   Male   46  Marked
# 6   23  Treated   Male   58  Marked
# 7   75  Treated   Male   59  None
# 8   39  Treated   Male   59  Marked
# 9   33  Treated   Male   63  None
# 10  55  Treated   Male   63  None
# 11  30  Treated   Male   64  None
# 12   5  Treated   Male   64  Some
# 13  63  Treated   Male   69  None
# 14  83  Treated   Male   70  Marked
# 15  66  Treated   Female 23  None
# 16  40  Treated   Female 32  None
# 17   6  Treated   Female 37  Some
# 18   7  Treated   Female 41  None
# 19  72  Treated   Female 41  Marked
# 20  37  Treated   Female 48  None
# 21  82  Treated   Female 48  Marked
# 22  53  Treated   Female 55  Marked
# 23  79  Treated   Female 55  Marked
# 24  26  Treated   Female 56  Marked
# 25  28  Treated   Female 57  Marked
# 26  60  Treated   Female 57  Marked
# ...

# %% [markdown]
# Q. Print shape of the dataset

# %%
# Out:
# [1] 84  5

# %%
dim(Arthritis)
# Out:
# [1] 84  5

# %% [markdown]
# Q. Print head, tail of the dataset

# %%
# Out:
#   ID Treatment Sex  Age Improved
# 1 57 Treated   Male 27  Some
# 2 46 Treated   Male 29  None
# 3 77 Treated   Male 30  None
# 4 17 Treated   Male 32  Marked
# 5 36 Treated   Male 46  Marked
# 6 23 Treated   Male 58  Marked

# %%
head(Arthritis)
tail(Arthritis)
# Out:
#   ID Treatment Sex  Age Improved
# 1 57 Treated   Male 27  Some
# 2 46 Treated   Male 29  None
# 3 77 Treated   Male 30  None
# 4 17 Treated   Male 32  Marked
# 5 36 Treated   Male 46  Marked
# 6 23 Treated   Male 58  Marked
#    ID Treatment Sex    Age Improved
# 79 67 Placebo   Female 65  Marked
# 80 32 Placebo   Female 66  None
# 81 42 Placebo   Female 66  None
# 82 15 Placebo   Female 66  Some
# 83 71 Placebo   Female 68  Some
# 84  1 Placebo   Female 74  Marked

# %% [markdown]
# ### Vectors , matrix

# %%
a <- c(1, 2, 5, 3, 6, -2, 4)
b <- c("one", "two", "three")
c <- c(TRUE, TRUE, TRUE, FALSE, TRUE, FALSE)

# %% [markdown]
# Q. Print 3rd values in vector a. Print 2nd-6th values in vector a

# %%
# Out:
# [1] 5
# [1]  2  5  3  6 -2

# %%
a[3]
a[2:6]
# Out:
# [1] 5
# [1]  2  5  3  6 -2

# %% [markdown]
# Q. Create a matrix of size 5x4

# %%
mat <- matrix(seq(1, 20, 1),nrow=5, ncol=4)
mat
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1     6   11   16
# [2,] 2     7   12   17
# [3,] 3     8   13   18
# [4,] 4     9   14   19
# [5,] 5    10   15   20

# %% [markdown]
# More fancy matrix

# %%
cells    <- c(1,26,24,68)
rnames   <- c("R1", "R2")
cnames   <- c("C1", "C2") 
mat <- matrix(cells, nrow=2, ncol=2, byrow=TRUE,
                   dimnames=list(rnames, cnames))
mat
# Out:
#    C1 C2
# R1  1 26
# R2 24 68

# %% [markdown]
# ### Data Frame

# %%
df <- Arthritis

# %%
df
# Out:
#     ID  Treatment Sex    Age Improved
# 1   57  Treated   Male   27  Some
# 2   46  Treated   Male   29  None
# 3   77  Treated   Male   30  None
# 4   17  Treated   Male   32  Marked
# 5   36  Treated   Male   46  Marked
# 6   23  Treated   Male   58  Marked
# 7   75  Treated   Male   59  None
# 8   39  Treated   Male   59  Marked
# 9   33  Treated   Male   63  None
# 10  55  Treated   Male   63  None
# 11  30  Treated   Male   64  None
# 12   5  Treated   Male   64  Some
# 13  63  Treated   Male   69  None
# 14  83  Treated   Male   70  Marked
# 15  66  Treated   Female 23  None
# 16  40  Treated   Female 32  None
# 17   6  Treated   Female 37  Some
# 18   7  Treated   Female 41  None
# 19  72  Treated   Female 41  Marked
# 20  37  Treated   Female 48  None
# 21  82  Treated   Female 48  Marked
# 22  53  Treated   Female 55  Marked
# 23  79  Treated   Female 55  Marked
# 24  26  Treated   Female 56  Marked
# 25  28  Treated   Female 57  Marked
# 26  60  Treated   Female 57  Marked
# ...

# %% [markdown]
# Q. Make a summary of df

# %%
# Out:
#        ID          Treatment      Sex          Age          Improved
#  Min.   : 1,00   Placebo:43   Female:59   Min.   :23,00   None  :42
#  1st Qu.:21,75   Treated:41   Male  :25   1st Qu.:46,00   Some  :14
#  Median :42,50                            Median :57,00   Marked:28
#  Mean   :42,50                            Mean   :53,36
#  3rd Qu.:63,25                            3rd Qu.:63,00
#  Max.   :84,00                            Max.   :74,00

# %%
summary(df)
# Out:
#        ID          Treatment      Sex          Age          Improved
#  Min.   : 1,00   Placebo:43   Female:59   Min.   :23,00   None  :42
#  1st Qu.:21,75   Treated:41   Male  :25   1st Qu.:46,00   Some  :14
#  Median :42,50                            Median :57,00   Marked:28
#  Mean   :42,50                            Mean   :53,36
#  3rd Qu.:63,25                            3rd Qu.:63,00
#  Max.   :84,00                            Max.   :74,00

# %% [markdown]
# Q. Print Values of column Age, and column Sex

# %%
# Out:
#  [1] 27 29 30 32 46 58 59 59 63 63 64 64 69 70 23 32 37 41 41 48 48 55 55 56 57
# [26] 57 57 58 59 59 60 61 62 62 66 67 68 68 69 69 70 37 44 50 51 52 53 59 59 62
# [51] 62 63 23 30 30 31 32 33 37 44 45 46 48 49 51 53 54 54 54 55 57 57 58 59 59
# [76] 61 63 64 65 66 66 66 68 74

# %%
df$Age
# Out:
#  [1] 27 29 30 32 46 58 59 59 63 63 64 64 69 70 23 32 37 41 41 48 48 55 55 56 57
# [26] 57 57 58 59 59 60 61 62 62 66 67 68 68 69 69 70 37 44 50 51 52 53 59 59 62
# [51] 62 63 23 30 30 31 32 33 37 44 45 46 48 49 51 53 54 54 54 55 57 57 58 59 59
# [76] 61 63 64 65 66 66 66 68 74

# %%
# Out:
#  [1] Male   Male   Male   Male   Male   Male   Male   Male   Male   Male
# [11] Male   Male   Male   Male   Female Female Female Female Female Female
# [21] Female Female Female Female Female Female Female Female Female Female
# [31] Female Female Female Female Female Female Female Female Female Female
# [41] Female Male   Male   Male   Male   Male   Male   Male   Male   Male
# [51] Male   Male   Female Female Female Female Female Female Female Female
# [61] Female Female Female Female Female Female Female Female Female Female
# [71] Female Female Female Female Female Female Female Female Female Female
# [81] Female Female Female Female
# Levels: Female Male

# %%
df$Sex
# Out:
#  [1] Male   Male   Male   Male   Male   Male   Male   Male   Male   Male
# [11] Male   Male   Male   Male   Female Female Female Female Female Female
# [21] Female Female Female Female Female Female Female Female Female Female
# [31] Female Female Female Female Female Female Female Female Female Female
# [41] Female Male   Male   Male   Male   Male   Male   Male   Male   Male
# [51] Male   Male   Female Female Female Female Female Female Female Female
# [61] Female Female Female Female Female Female Female Female Female Female
# [71] Female Female Female Female Female Female Female Female Female Female
# [81] Female Female Female Female
# Levels: Female Male

# %% [markdown]
# Q. Print only 2 columns ID, Treatment

# %%
# Out:
#     ID  Treatment
# 1   57  Treated
# 2   46  Treated
# 3   77  Treated
# 4   17  Treated
# 5   36  Treated
# 6   23  Treated
# 7   75  Treated
# 8   39  Treated
# 9   33  Treated
# 10  55  Treated
# 11  30  Treated
# 12   5  Treated
# 13  63  Treated
# 14  83  Treated
# 15  66  Treated
# 16  40  Treated
# 17   6  Treated
# 18   7  Treated
# 19  72  Treated
# 20  37  Treated
# 21  82  Treated
# 22  53  Treated
# 23  79  Treated
# 24  26  Treated
# 25  28  Treated
# 26  60  Treated
# 27  22  Treated
# 28  27  Treated
# 29   2  Treated
# 30  59  Treated
# ... ... ...
# 55  29  Placebo
# 56  50  Placebo
# 57  38  Placebo
# 58  35  Placebo
# 59  51  Placebo
# 60  54  Placebo
# 61  76  Placebo
# 62  16  Placebo
# 63  69  Placebo
# 64  31  Placebo
# 65  20  Placebo
# 66  68  Placebo
# 67  81  Placebo
# 68   4  Placebo
# 69  78  Placebo
# 70  70  Placebo
# 71  49  Placebo
# 72  10  Placebo
# 73  47  Placebo
# 74  44  Placebo
# 75  24  Placebo
# 76  48  Placebo
# 77  19  Placebo
# ...

# %%
library(dplyr)
# findFn("select")
select(df, ID, Treatment)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#     ID  Treatment
# 1   57  Treated
# 2   46  Treated
# 3   77  Treated
# 4   17  Treated
# 5   36  Treated
# 6   23  Treated
# 7   75  Treated
# 8   39  Treated
# 9   33  Treated
# 10  55  Treated
# 11  30  Treated
# 12   5  Treated
# 13  63  Treated
# 14  83  Treated
# 15  66  Treated
# 16  40  Treated
# 17   6  Treated
# 18   7  Treated
# 19  72  Treated
# 20  37  Treated
# 21  82  Treated
# 22  53  Treated
# 23  79  Treated
# 24  26  Treated
# 25  28  Treated
# 26  60  Treated
# 27  22  Treated
# 28  27  Treated
# 29   2  Treated
# 30  59  Treated
# ... ... ...
# 55  29  Placebo
# 56  50  Placebo
# 57  38  Placebo
# 58  35  Placebo
# 59  51  Placebo
# 60  54  Placebo
# 61  76  Placebo
# 62  16  Placebo
# 63  69  Placebo
# 64  31  Placebo
# 65  20  Placebo
# 66  68  Placebo
# ...

# %% [markdown]
# Q. Select only some rows and columns

# %%
newdata <- subset(df, Sex == "Male", select=c(Sex, Age, Improved)) 
head(newdata, 3)
# Out:
#   Sex  Age Improved
# 1 Male 27  Some
# 2 Male 29  None
# 3 Male 30  None

# %% [markdown]
# Q. Read file titanic into a dataframe

# %%
# Out:
#     PassengerId Survived Pclass
# 1    1          0        3
# 2    2          1        1
# 3    3          1        3
# 4    4          1        1
# 5    5          0        3
# 6    6          0        3
# 7    7          0        1
# 8    8          0        3
# 9    9          1        3
# 10  10          1        2
# 11  11          1        3
# 12  12          1        1
# 13  13          0        3
# 14  14          0        3
# 15  15          0        3
# 16  16          1        2
# 17  17          0        3
# 18  18          1        2
# 19  19          0        3
# 20  20          1        3
# 21  21          0        2
# 22  22          1        2
# 23  23          1        3
# 24  24          1        1
# 25  25          0        3
# 26  26          1        3
# 27  27          0        3
# 28  28          0        1
# 29  29          1        3
# 30  30          0        3
# ... ...         ...      ...
# 862 862         0        2
# 863 863         1        1
# ...

# %% [markdown]
# Some datasets you can just call them directly.
#
# Q. Load datasets iris

# %%
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5,1          3,5         1,4          0,2         setosa
# 2   4,9          3,0         1,4          0,2         setosa
# 3   4,7          3,2         1,3          0,2         setosa
# 4   4,6          3,1         1,5          0,2         setosa
# 5   5,0          3,6         1,4          0,2         setosa
# 6   5,4          3,9         1,7          0,4         setosa
# 7   4,6          3,4         1,4          0,3         setosa
# 8   5,0          3,4         1,5          0,2         setosa
# 9   4,4          2,9         1,4          0,2         setosa
# 10  4,9          3,1         1,5          0,1         setosa
# 11  5,4          3,7         1,5          0,2         setosa
# 12  4,8          3,4         1,6          0,2         setosa
# 13  4,8          3,0         1,4          0,1         setosa
# 14  4,3          3,0         1,1          0,1         setosa
# ...

# %%
df <- read.csv("data/titanic.csv")

# %% [markdown]
# ### Charts

# %%
attach(mtcars) # to load all columns into it name

# %%
mtcars
# Out:
#                     mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# Mazda RX4           21,0 6   160,0 110 3,90 2,620 16,46 0  1  4    4
# Mazda RX4 Wag       21,0 6   160,0 110 3,90 2,875 17,02 0  1  4    4
# Datsun 710          22,8 4   108,0  93 3,85 2,320 18,61 1  1  4    1
# Hornet 4 Drive      21,4 6   258,0 110 3,08 3,215 19,44 1  0  3    1
# Hornet Sportabout   18,7 8   360,0 175 3,15 3,440 17,02 0  0  3    2
# Valiant             18,1 6   225,0 105 2,76 3,460 20,22 1  0  3    1
# Duster 360          14,3 8   360,0 245 3,21 3,570 15,84 0  0  3    4
# Merc 240D           24,4 4   146,7  62 3,69 3,190 20,00 1  0  4    2
# Merc 230            22,8 4   140,8  95 3,92 3,150 22,90 1  0  4    2
# Merc 280            19,2 6   167,6 123 3,92 3,440 18,30 1  0  4    4
# Merc 280C           17,8 6   167,6 123 3,92 3,440 18,90 1  0  4    4
# Merc 450SE          16,4 8   275,8 180 3,07 4,070 17,40 0  0  3    3
# Merc 450SL          17,3 8   275,8 180 3,07 3,730 17,60 0  0  3    3
# ...

# %%
wt
# Out:
#  [1] 2,620 2,875 2,320 3,215 3,440 3,460 3,570 3,190 3,150 3,440 3,440 4,070
# [13] 3,730 3,780 5,250 5,424 5,345 2,200 1,615 1,835 2,465 3,520 3,435 3,840
# [25] 3,845 1,935 2,140 1,513 3,170 2,770 3,570 2,780

# %% [markdown]
# Of course, you can always use:

# %%
mtcars$wt
# Out:
#  [1] 2,620 2,875 2,320 3,215 3,440 3,460 3,570 3,190 3,150 3,440 3,440 4,070
# [13] 3,730 3,780 5,250 5,424 5,345 2,200 1,615 1,835 2,465 3,520 3,435 3,840
# [25] 3,845 1,935 2,140 1,513 3,170 2,770 3,570 2,780

# %% [markdown]
# Q. Scatter plot wt versus mgp

# %%
plot(wt, mpg)
# Out:
# plot without title

# %% [markdown]
# Q. Add a regression line fitting wt and mpg into the plot.

# %%
plot(wt, mpg)
abline(lm(wt~mpg), color="red")
# Out:
# Warning message in int_abline(a = a, b = b, h = h, v = v, untf = untf, ...):
# “"color" n'est pas un paramètre graphique”
# plot without title

# %% [markdown]
# Q. Put name next to the plot

# %%
plot(wt, mpg)
text(wt, mpg, cex=0.7, pos=3)
# Out:
# plot without title

# %% [markdown]
# Q. Plot multiple scatter plots. Hint, use "par"

# %%
par(mfrow=c(2,2))
plot(wt,mpg, main="Scatterplot of wt vs. mpg")
plot(wt,disp, main="Scatterplot of wt vs disp")
hist(wt, main="Histogram of wt")
boxplot(wt, main="Boxplot of wt")
# Out:
# Plot with title “Boxplot of wt”

# %% [markdown]
# Q. And another fancy chart-combination

# %%
layout(matrix(c(1, 1, 2, 3), 2, 2, byrow = TRUE),
       widths=c(3, 1), heights=c(1, 2))
hist(wt)
hist(mpg)
hist(disp)
# Out:
# Plot with title “Histogram of disp”

# %%
detach(mtcars)
